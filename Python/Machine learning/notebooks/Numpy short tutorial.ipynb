# %%
# %config IPCompleter.greedy=True
# %config IPCompleter.greedy=True
# %config Completer.use_jedi = False

#import
import numpy as np;
import pandas as pd;

#make array all zeros
arr = np.zeros(3)
arr.shape

#make array all 1s
arr1 = np.ones(10);

print('Size is : {0}'.format(arr1.size) );
print('Shape is : {0}'.format(arr1.shape) );

#rage from 1 to 3
print(arr1[1:3])

#change shape
arr1.shape = (10, 1);

print('New shape is : {0}'.format(arr1.shape) );
# Out:
# Size is : 10
# Shape is : (10,)
# [1. 1.]
# New shape is : (10, 1)

# %%
#load image
from skimage import io;

img1 = io.imread('./imgs/1_1.png');

img1.shape

import matplotlib.pyplot as plt;
plt.imshow(img1);

# %%
#https://www.youtube.com/watch?v=dcqPhpY7tWk&t=209s

airl_data = pd.read_csv('.\\data\\airline_passenger_satisfaction.csv.txt');
airl_data.head()
# Out:
#    Gender      customer_type  age   type_of_travel customer_class  \
# 0    Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1    Male  disloyal Customer   25  Business travel       Business
# 2  Female     Loyal Customer   26  Business travel       Business
# 3  Female     Loyal Customer   25  Business travel       Business
# 4    Male     Loyal Customer   61  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    ease_of_online_booking  gate_location  ...  inflight_entertainment  \
# ...

# %%
airl_data.describe()
# Out:
#                  age  flight_distance  inflight_wifi_service  \
# count  129880.000000    129880.000000          129880.000000
# mean       39.427957      1190.316392               2.728696
# std        15.119360       997.452477               1.329340
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       844.000000               3.000000
# 75%        51.000000      1744.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        departure_arrival_time_convenient  ease_of_online_booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %%
pd.value_counts(airl_data['Gender']).plot.bar()

# %%
pd.value_counts(airl_data['flight_distance']).plot.hist();

# %%
pd.value_counts(airl_data['online_boarding']).plot.hist();

# %%
airl_data.groupby(['arrival_delay_in_minutes']).mean()
# Out:
#                                 age  flight_distance  inflight_wifi_service  \
# arrival_delay_in_minutes
# 0.0                       39.546960      1196.713318               2.767006
# 1.0                       39.732435      1181.390244               2.751001
# 2.0                       39.199072      1150.795129               2.731349
# 3.0                       40.160934      1196.926290               2.748567
# 4.0                       39.670881      1209.941846               2.774547
# ...                             ...              ...                    ...
# 970.0                     30.000000      1598.000000               1.000000
# 1011.0                    49.000000      1959.000000               1.000000
# 1115.0                     8.000000      1144.000000               2.000000
# 1280.0                    32.000000      2916.000000               2.000000
# 1584.0                    47.000000      1120.000000               2.000000
#
# ...
